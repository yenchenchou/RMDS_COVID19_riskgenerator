# %%
import json
import os
import re
import time

import numpy as np
import pandas as pd

from collections import defaultdict
from geopy.geocoders import Nominatim

# %matplotlib inline
pd.options.display.max_columns = 99
os.chdir("/Users/yenchenchou/Documents/RMDS_YC/RiskScore/RMDS_COVID19_riskgenerator")

# %%
df = pd.read_csv(
    "data/external/Core-USA-July2020-Release-CORE_POI-2020_06-2020-07-13/core_poi-part1.csv.gz",
    compression="gzip")

# %%
df.head(5)
# Out:
#                     safegraph_place_id parent_safegraph_place_id  \
# 0  sg:0026d587c9b145b58272cbac7bdea56a                       NaN
# 1  sg:0037c4dc85f642c6aeaaf318e41b1bf7                       NaN
# 2  sg:0041bdf50f984826acd68ce19922ecd4                       NaN
# 3  sg:005761d9681947629bf02a64cfd4aec2                       NaN
# 4  sg:007236f9d77d4158bbd4d55f39d98e49                       NaN
#
#                    location_name safegraph_brand_ids brands  \
# 0             Vallone A John DDS                 NaN    NaN
# 1   Mitchell Cosmetology College                 NaN    NaN
# 2            Sullivan Chris M Dr                 NaN    NaN
# 3  U Pick Carlsbad Strawberry Co                 NaN    NaN
# 4         CJ's Auto Glass Repair                 NaN    NaN
#
#                                         top_category  \
# 0                                Offices of Dentists
# 1   Colleges, Universities, and Professional Schools
# 2  Other Professional, Scientific, and Technical ...
# 3                              Specialty Food Stores
# 4  Lumber and Other Construction Materials Mercha...
#
#                                        sub_category  naics_code   latitude  \
# 0                               Offices of Dentists    621210.0  41.158062
# 1  Colleges, Universities, and Professional Schools    611310.0  33.243518
# 2                               Veterinary Services    541940.0  32.153705
# 3                       Fruit and Vegetable Markets    445230.0  33.135632
# 4  Other Construction Material Merchant Wholesalers    423390.0  40.470182
#
#     longitude          street_address            city region  postal_code  \
# 0  -87.891611  35 Briarcliff Prof Ctr     Bourbonnais     IL        60914
# 1  -86.816563            116 1st St S       Alabaster     AL        35007
# 2  -91.715387           403 Eighth St       Winnsboro     LA        71295
# 3 -117.326437          1000 Cannon Rd        Carlsbad     CA        92008
# 4  -74.408106      190 State Route 18  East Brunswick     NJ         8816
#
#   iso_country_code  phone_number  \
# 0               US  1.815939e+10
# 1               US  1.205664e+10
# 2               US           NaN
# 3               US           NaN
# 4               US  1.732994e+10
#
#                                           open_hours category_tags opened_on  \
# 0                                                NaN           NaN       NaN
# 1  { "Mon": [], "Tue": [["12:00", "16:00"]], "Wed...           NaN       NaN
# 2                                                NaN           NaN       NaN
# 3  { "Mon": [["9:00", "18:00"]], "Tue": [["9:00",...           NaN       NaN
# 4  { "Mon": [["8:00", "20:00"]], "Tue": [["8:00",...           NaN       NaN
#
#   closed_on tracking_opened_since tracking_closed_since
# 0       NaN                   NaN               2019-07
# 1       NaN                   NaN               2019-07
# 2       NaN                   NaN               2019-07
# 3       NaN                   NaN               2019-07
# 4       NaN                   NaN               2019-07

# %%
df.shape
# Out:
# (1179095, 22)

# %%
def data_filter(df):
    
    filter_ls = ["Restaurants and Other Eating Places", "Grocery Stores"]
    #     df = df[df["top_category"].isin(filter_ls)].copy()
    
    df = df[df["region"] == "CA"].copy()
    df = df[["safegraph_place_id", 
            "latitude",
            "longitude",
            "city",
            "postal_code"]]
    df["community"] = df["postal_code"].apply(lambda x: mapping(x))
    df = df[df["community"].notnull()]
    
    return df


def mapping(x):
    with open("data/internal/zipcode_mapper.json") as file:
        mapper_dict = json.load(file)
    mapper_dict = {str(key):val for key, val in mapper_dict.items()}
    try: 
        return mapper_dict[str(x)]
    except:
        pass

# %%
now = time.time()
df_filter = data_filter(df)
later = time.time()
print(later - now)
# Out:
# 41.280043601989746
